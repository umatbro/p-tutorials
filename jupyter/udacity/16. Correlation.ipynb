# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
miles = pd.Series([60000, 80000, 90000, 100000, 120000], name='miles')
values = pd.Series([12000, 10000, 9000, 7500, 6000], name='values')

df = pd.DataFrame([miles, values]).T
df
# Out:
#     miles  values
# 0   60000   12000
# 1   80000   10000
# 2   90000    9000
# 3  100000    7500
# 4  120000    6000

# %%
ax = df.plot.scatter(x='miles', y='values')

# %% [markdown]
# ## Correlation coefficient
#
# r = cov(x, y)/s_x * s_y
#
# s_x - standard deviation of x
# s_y - standard deviation of y
#
# r<sup>2<sup> - percentage of the variation in Y explained by the variation in X

# %%
data = pd.read_csv('spreadsheets/correlations.csv')
data
# Out:
#     dentist  temp  age  year  pets  eggs     icons  emails  party
# 0         1  30.0   26  1987     0     0         8       0     30
# 1        10  10.0   69  1944     0     0         8       0      0
# 2        10  20.0   39  1974     1     0        34     500     60
# 3         5   NaN   26  1987     0    12        22    1267      0
# 4         3  15.0   31  1982     0     3        28       1     30
# 5        12   7.0   42  1971     1    12        14       0     60
# 6         0  21.0   52  1961     3    22         6       0     15
# 7         3   6.0   43  1970     2     9        29      20      0
# 8         0  15.0   53  1960     0     6        20      10     30
# 9        10  15.5   32  1981     2     7       150       0    -10
# 10        8  21.0   15  1998     0    23         6      21    -30
# 11        5  24.0   44  1969     0     8        57     649     15
# 12        6  22.0   66  1947     0     6         1       0      0
# ...

# %%
data.plot.scatter(x='age', y='party')
data.plot.scatter(x='age', y='pets')

# %%
# correlations
data[['age', 'party', 'pets']].corr()
# Out:
#             age     party      pets
# age    1.000000 -0.164214  0.375765
# party -0.164214  1.000000 -0.047704
# pets   0.375765 -0.047704  1.000000

# %%
data[['age', 'pets']].append({'age': 20, 'pets': 8}, ignore_index=True).corr()
# Out:
#            age      pets
# age   1.000000  0.231481
# pets  0.231481  1.000000
