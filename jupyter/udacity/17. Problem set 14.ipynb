# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spreadsheets/gestation_and_longevity(ps14).csv')
df
# Out:
#            Animal  Gestation (days)  Longevity (years)
# 0          Baboon               187                 20
# 1     Bear, Black               219                 18
# 2   Bear, Grizzly               225                 25
# 3     Bear, Polar               240                 20
# 4          Beaver               105                  5
# 5         Buffalo               285                 15
# 6           Camel               406                 12
# 7             Cat                63                 12
# 8      Chimpanzee               230                 20
# 9        Chipmunk                31                  6
# 10            Cow               284                 15
# 11           Deer               201                  8
# 12            Dog                61                 12
# 13         Donkey               365                 12
# 14       Elephant               645                 40
# 15            Elk               250                 15
# ...

# %%
df.plot.scatter(*df.columns[1:])

# %%
df.corr()
# Out:
#                    Gestation (days)  Longevity (years)
# Gestation (days)           1.000000           0.589313
# Longevity (years)          0.589313           1.000000

# %%
df.corr() ** 2
# Out:
#                    Gestation (days)  Longevity (years)
# Gestation (days)           1.000000           0.347289
# Longevity (years)          0.347289           1.000000
